# %% [markdown]
# <a href="https://colab.research.google.com/github/jamshid-ds/sql3_mohirdev_nbs/blob/main/sql_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2023-12-04 08:10:07--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 104.21.30.141, 172.67.172.250, 2606:4700:3037::6815:1e8d, ...
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|104.21.30.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.04s
#
# 2023-12-04 08:10:07 (7.97 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db = sql.connect('chinook.db')
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT (*) FROM artists")
cursor.fetchone()
# Out:
# (275,)

# %%
cursor.execute("PRAGMA table_info(customers)")
cursor.fetchall()
# Out:
# [(0, 'CustomerId', 'INTEGER', 1, None, 1),
#  (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0),
#  (2, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Company', 'NVARCHAR(80)', 0, None, 0),
#  (4, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (5, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (6, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (7, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (9, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (10, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (11, 'Email', 'NVARCHAR(60)', 1, None, 0),
#  (12, 'SupportRepId', 'INTEGER', 0, None, 0)]

# %%
 cursor.execute("SELECT * FROM customers")
 mijozlar = cursor.fetchall()

# %%
query = "SELECT CustomerId, Firstname, LastName, Phone, Country FROM customers ORDER BY Country LIMIT 20"
df = pd.read_sql(query, db, index_col="CustomerId")
df
# Out:
#             FirstName     LastName                Phone         Country
# CustomerId
# 56              Diego    Gutiérrez  +54 (0)11 4311 4333       Argentina
# 55               Mark       Taylor   +61 (02) 9332 3633       Australia
# 7              Astrid       Gruber       +43 01 5134505         Austria
# 8                Daan      Peeters     +32 02 219 03 03         Belgium
# 1                Luís    Gonçalves   +55 (12) 3923-5555          Brazil
# 10            Eduardo      Martins   +55 (11) 3033-5446          Brazil
# 11          Alexandre        Rocha   +55 (11) 3055-3278          Brazil
# 12            Roberto      Almeida   +55 (21) 2271-7000          Brazil
# 13           Fernanda        Ramos   +55 (61) 3363-5547          Brazil
# 3            François     Tremblay    +1 (514) 721-4711          Canada
# 14               Mark      Philips    +1 (780) 434-4554          Canada
# 15           Jennifer     Peterson    +1 (604) 688-2255          Canada
# ...

# %%
query = 'SELECT DISTINCT Country FROM customers'
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Brazil',),
#  ('Germany',),
#  ('Canada',),
#  ('Norway',),
#  ('Czech Republic',),
#  ('Austria',),
#  ('Belgium',),
#  ('Denmark',),
#  ('USA',),
#  ('Portugal',),
#  ('France',),
#  ('Finland',),
#  ('Hungary',),
#  ('Ireland',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Spain',),
#  ('Sweden',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Argentina',),
#  ('Chile',),
#  ('India',)]

# %%
pd.read_sql(query,db)
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %%
query = 'SELECT * FROM customers WHERE country="Italy" OR country="USA" ORDER BY Country'
pd.read_sql(query, db)
# Out:
#     CustomerId FirstName    LastName                Company  \
# 0           47     Lucas     Mancini                   None
# 1           16     Frank      Harris            Google Inc.
# 2           17      Jack       Smith  Microsoft Corporation
# 3           18  Michelle      Brooks                   None
# 4           19       Tim       Goyer             Apple Inc.
# 5           20       Dan      Miller                   None
# 6           21     Kathy       Chase                   None
# 7           22   Heather     Leacock                   None
# 8           23      John      Gordon                   None
# 9           24     Frank     Ralston                   None
# 10          25    Victor     Stevens                   None
# 11          26   Richard  Cunningham                   None
# 12          27   Patrick        Gray                   None
# 13          28     Julia     Barnett                   None
#
# ...
